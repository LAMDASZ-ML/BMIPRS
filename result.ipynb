# %%
dataset_name=["caltech101", "dtd", "eurosat", "fgvc_aircraft", "food101", "imagenet","oxford_flowers", "oxford_pets", "stanford_cars", "sun397", "ucf101"]
# dataset_name=["fgvc_aircraft", "ucf101" "sun397",]
print(dataset_name)
# Out:
# ['caltech101', 'dtd', 'eurosat', 'fgvc_aircraft', 'food101', 'imagenet', 'oxford_flowers', 'oxford_pets', 'stanford_cars', 'sun397', 'ucf101']

# %%
# 1.
# data_path_train="/data0/lvsl/Code/BITP/output/base2new/train_base/vit_b16_c2_ep10_ctx2_dp9TT_warmup5_BZ4_ex"
# data_path_test="/data0/lvsl/Code/BITP/output/base2new/test_new/vit_b16_c2_ep10_ctx2_dp9TT_warmup5_BZ4_ex"
# 2.
# data_path_train="/data0/lvsl/Code/BITP/output/base2new/train_base/BMIP_ctx3_dp9_lr2_123"
# data_path_test="/data0/lvsl/Code/BITP/output/base2new/test_new/BMIP_ctx3_dp9_lr2_123"
# 3. 
# data_path_train="/data0/lvsl/Code/BITP/output/base2new/train_base/BMIP_seed4"
# data_path_test="/data0/lvsl/Code/BITP/output/base2new/test_new/BMIP_seed4"
# 4.
# data_path_train="/data0/lvsl/Code/BITP/output/base2new/train_base/vit_b16_c2_ep15_ctx2_dp9TT_warmup5_BZ4_exMLP"
# data_path_test="/data0/lvsl/Code/BITP/output/base2new/test_new/vit_b16_c2_ep15_ctx2_dp9TT_warmup5_BZ4_exMLP"
# 5.
# data_path_train="/data0/lvsl/Code/BITP/output/base2new/train_base/BMIP_seed123_weight_threshold"
# data_path_test="/data0/lvsl/Code/BITP/output/base2new/test_new/BMIP_seed123_weight_threshold"
# 6. 
# data_path_train="/data0/lvsl/Code/BITP/output/base2new/train_base/BMIP_seed123_w_0.003"
# data_path_test="/data0/lvsl/Code/BITP/output/base2new/test_new/BMIP_seed123_w_0.003"
# 7. vit_b16_c2_ep15_ctx2_dp9TT_warmup2_BZ4_ex
# data_path_train="/data0/lvsl/Code/BITP/output/base2new/train_base/vit_b16_c2_ep15_ctx2_dp9TT_warmup2_BZ4_ex"
# data_path_test="/data0/lvsl/Code/BITP/output/base2new/test_new/vit_b16_c2_ep15_ctx2_dp9TT_warmup2_BZ4_ex"
# 8. BMIP_seed123_w_0.002
# data_path_train="/data0/lvsl/Code/BITP/output/base2new/train_base/BMIP_seed123_w_0.002"
# data_path_test="/data0/lvsl/Code/BITP/output/base2new/test_new/BMIP_seed123_w_0.002"
# 9. BMIP_seed123_w_25
# data_path_train="/data0/lvsl/Code/BITP/output/base2new/train_base/BMIP_seed123_w_25"
# data_path_test="/data0/lvsl/Code/BITP/output/base2new/test_new/BMIP_seed123_w_25"
# 10. BMIP_seed29_w_2
data_path_train="/home/lvsl/Code/Base2new/BMIP/output/base2new/train_base/vit_bitp_ctx4_ep20TT_adam_PromptSRCseed16dp9lr21"
data_path_test="/home/lvsl/Code/Base2new/BMIP/output/base2new/test_new/vit_bitp_ctx4_ep20TT_adam_PromptSRCseed16dp9lr21"
# 11. vit_b16_c2_ep15_ctx2_dp9TT_warmup5_BZ4_ex_seed11PT4
# data_path_train="/mnt/hdd/lvsl/output/base2new/train_base/vit_bitp_ctx4_ep20TT_PromptSRC"
# data_path_test="/mnt/hdd/lvsl/output/base2new/test_new/vit_bitp_ctx4_ep20TT_PromptSRC"
# data_path_eva="output/base2new/test_eva/vit_b16_c2_ep5_batch4_2ctxUPT"

# %%
# 打开文件result.txt
with open("result.md", "w", ) as f:
    f.write("| 数据集        | seed1 tr | seed1 test | seed2 tr | seed2 test | seed3 tr | seed3 test | HM   | " + "\n")
    f.write("| ------------- | -------- | ---------- | -------- | ---------- | -------- | ---------- | ---- |" + "\n")
    for dataset in dataset_name:
        path_train = data_path_train + '/' + dataset + '/'
        path_test = data_path_test + '/' + dataset + '/'
        output_train = !python parse_test_res.py --test-log {path_train}
        output_test = !python parse_test_res.py --test-log {path_test}
        # print(path_train)
        # print(output_train)
        accuary = "|"
        print(dataset)
  
        for i in range(0, 3):
            print(i)
            if dataset == 'imagenet':
                continue
                # print(output_train)
                # print(output_test)
            accuary += output_train[5].split('\t')[i] + '|' + output_test[5].split('\t')[i] + '|'
        f.write("|" + dataset + accuary + '\n')
    f.write("| average       |          |            |          |            |          |            |      |")
    f.close()
# Out:
# caltech101
# 0
# 1
# 2
# dtd
# 0
# 1
# 2
# eurosat
# 0
# 1
# 2
# fgvc_aircraft
# 0
# 1
# 2
# food101
# 0
# 1
# 2
# imagenet
# 0
# 1
# 2
# oxford_flowers
# 0
# 1
# 2
# oxford_pets
# 0
# 1
# 2
# stanford_cars
# 0
# 1
# 2
# sun397
# 0
# 1
# 2
# ucf101
# 0
# 1
# 2

# %% [markdown]
# | 数据集        | seed1 tr | seed1 test | seed2 tr | seed2 test | seed3 tr | seed3 test | HM   |
# | ------------- | -------- | ---------- | -------- | ---------- | -------- | ---------- | ---- |
# | caltech       |          |            |          |            |          |            |      |
# | dtd           |          |            |          |            |          |            |      |
# | eurosat       |          |            |          |            |          |            |      |
# | fgvc_aircraft |          |            |          |            |          |            |      |
# | food          |          |            |          |            |          |            |      |
# | imagenet      |          |            |          |            |          |            |      |
# | o f           |          |            |          |            |          |            |      |
# | o p           |          |            |          |            |          |            |      |
# | st cars       |          |            |          |            |          |            |      |
# | sun           |          |            |          |            |          |            |      |
# | ucf101        |          |            |          |            |          |            |      |
# | average       |          |            |          |            |          |            |      |

# %%
data_path_eva="/home/lvsl/Code/Base2new/BMIP/output/base2new/test_all/BMIP_ctx2_dp9_lr2_123_pt4_seed48_ep15"
# 打开文件result.txt
with open("result_all.md", "w", ) as f:
    f.write("| 数据集        | seed1 tr | seed1 test | seed2 tr | seed2 test | seed3 tr | seed3 test | HM   | " + "\n")
    f.write("| ------------- | -------- | ---------- | -------- | ---------- | -------- | ---------- | ---- |" + "\n")
    for dataset in dataset_name:
        path_eva = data_path_eva + '/' + dataset + '/'
        
        output_eva = !python parse_test_res.py --test-log {path_eva}
        print(path_eva)
        accuary = "|"
        # if dataset == 
        for i in range(0, 3):
            accuary += " " + '|' + output_eva[5].split('\t')[i] + '|'
        f.write("|" + dataset + accuary + '\n')
    f.write("| average       |          |            |          |            |          |            |      |")
    f.close()
# Out:
# /home/lvsl/Code/Base2new/BMIP/output/base2new/test_all/BMIP_ctx2_dp9_lr2_123_pt4_seed48_ep15/caltech101/
# /home/lvsl/Code/Base2new/BMIP/output/base2new/test_all/BMIP_ctx2_dp9_lr2_123_pt4_seed48_ep15/dtd/
# /home/lvsl/Code/Base2new/BMIP/output/base2new/test_all/BMIP_ctx2_dp9_lr2_123_pt4_seed48_ep15/eurosat/
# /home/lvsl/Code/Base2new/BMIP/output/base2new/test_all/BMIP_ctx2_dp9_lr2_123_pt4_seed48_ep15/fgvc_aircraft/
# /home/lvsl/Code/Base2new/BMIP/output/base2new/test_all/BMIP_ctx2_dp9_lr2_123_pt4_seed48_ep15/food101/
# /home/lvsl/Code/Base2new/BMIP/output/base2new/test_all/BMIP_ctx2_dp9_lr2_123_pt4_seed48_ep15/imagenet/
# /home/lvsl/Code/Base2new/BMIP/output/base2new/test_all/BMIP_ctx2_dp9_lr2_123_pt4_seed48_ep15/oxford_flowers/
# /home/lvsl/Code/Base2new/BMIP/output/base2new/test_all/BMIP_ctx2_dp9_lr2_123_pt4_seed48_ep15/oxford_pets/
# /home/lvsl/Code/Base2new/BMIP/output/base2new/test_all/BMIP_ctx2_dp9_lr2_123_pt4_seed48_ep15/stanford_cars/
# ...

# %%
dataset_name=["caltech101", "dtd", "eurosat", "fgvc_aircraft", "food101", "imagenet", "oxford_flowers", "oxford_pets", "stanford_cars", "sun397", "ucf101", \
    "imagenetv2", "imagenet_a", "imagenet_r", "imagenet_sketch"]
# dataset_name=["fgvc_aircraft", "ucf101"]
print(dataset_name)

data_path_eva="/home/lvsl/Code/Base2new/BMIP_final_copy/output/evaluation/IVLP/vit_b16_c2_ep5_batch4_2+2ctx_16shots"
# 打开文件result.txt
with open("result_cs.md", "w", ) as f:
    f.write("| 数据集        | seed1 |seed2  | seed3 | average  | " + "\n")
    f.write("| ------------- | -------- | ---------- | -------- | ---- |" + "\n")
    for dataset in dataset_name:
        path_eva = data_path_eva + '/' + dataset + '/'
        
        output_eva = !python parse_test_res.py --test-log {path_eva}
        print(output_eva)
        accuary = "|"
        for i in range(0, 1):
            accuary +=  '' + output_eva[3].split('\t')[i] + '|'
        f.write("|" + dataset + accuary + "|"+ '\n')
    f.write("| average       | | |            |      |")
    f.close()
# Out:
# ['caltech101', 'dtd', 'eurosat', 'fgvc_aircraft', 'food101', 'imagenet', 'oxford_flowers', 'oxford_pets', 'stanford_cars', 'sun397', 'ucf101', 'imagenetv2', 'imagenet_a', 'imagenet_r', 'imagenet_sketch']
# ['Parsing files in /home/lvsl/Code/Base2new/BMIP_final_copy/output/evaluation/PromptSRC_BMIP/vit_bmipsrc_ctx4_ep10TT_CSSEED78/caltech101/', "['seed1']", 'file: /home/lvsl/Code/Base2new/BMIP_final_copy/output/evaluation/PromptSRC_BMIP/vit_bmipsrc_ctx4_ep10TT_CSSEED78/caltech101/seed1/log.txt. accuracy: 93.50%. ', '93.5', '===', 'Summary of directory: /home/lvsl/Code/Base2new/BMIP_final_copy/output/evaluation/PromptSRC_BMIP/vit_bmipsrc_ctx4_ep10TT_CSSEED78/caltech101/', '* accuracy: 93.50% +- 0.00%', '===']
# ...

# %%
# !mv /home/lvsl/Code/BITP/output/base2new/train_base/vit_b16_c2_ep20_ctx1_dp9TT_warmup2_BZ2_V3_seed24 /mnt/hdd/lvsl/base2new/train_base/vit_b16_c2_ep20_ctx1_dp9TT_warmup2_BZ2_V3_seed24/
# !mv /home/lvsl/Code/BITP/output/base2new/test_new/vit_b16_c2_ep20_ctx1_dp9TT_warmup2_BZ2_V3_seed24 /mnt/hdd/lvsl/base2new/test_new/vit_b16_c2_ep20_ctx1_dp9TT_warmup2_BZ2_V3_seed24/
